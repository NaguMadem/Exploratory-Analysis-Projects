# %%
# Web scapring
import requests, bs4

# %%
url = "https://data-flair.training/blogs/nlp-tutorial-natural-language-processing/"
req = requests.get(url)
soup = bs4.BeautifulSoup(req.text,"html5lib")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en-US"><head><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/><link href="http://gmpg.org/xfn/11" rel="profile"/><link href="https://data-flair.training/blogs/xmlrpc.php" rel="pingback"/><style data-origin="server" id="wfc-style-fonts-body">/* Setting : Default website font */
# body {
# font-family : Georgia,Georgia,serif!important;
# ...

# %%
# Getting the data from API
import numpy as np
import pandas as pd
import requests, json
import pprint

# %%
# joining the words in the address by '+'
add = "Upgrad, Nagu Madem, Ramesh Jamadar, Pradeep S, Suman GN"
split_address = add.split(" ")
address = "+".join(split_address)
print(address)
# Out:
# Upgrad,+Nagu+Madem,+Ramesh+Jamadar,+Pradeep+S,+Suman+GN

# %%
amount = u"₹50"
print('Default string: ', amount, '\n', 'Type of string', type(amount), '\n')
# Out:
# Default string:  ₹50
#  Type of string <class 'str'>

# %%
#Importing the necessart libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib.inline
import warnings
warnigs.filterwarnigs('ignore')
# Out:
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
#setting the current path 
os.chdir("C:\\Data Science\\Mindtree assignment\\")
Absenteesim_Data = pd.read_excel("Absenteeism_at_work.xls")
Absenteesim_Data.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#    Work load Average/day   ...  Disciplinary failure  Education  Son  \
# ...

# %%
Absenteesim_Data.tail()
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 735                     289                               36            13
# 736                     235                               11            14
# 737                     118                               14            13
# 738                     231                               35            14
# 739                     179                               45            14
#
#      Age  Work load Average/day   ...  Disciplinary failure  Education  Son  \
# ...

# %%
Absenteesim_Data.shape # Total 740 rows and 21 columns
# Out:
# (740, 21)

# %%
Absenteesim_Data.columns
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
Absenteesim_Data.dtypes # Checking the data types of the each column
# Out:
# ID                                 int64
# Reason for absence                 int64
# Month of absence                   int64
# Day of the week                    int64
# Seasons                            int64
# Transportation expense             int64
# Distance from Residence to Work    int64
# Service time                       int64
# Age                                int64
# Work load Average/day              int64
# Hit target                         int64
# Disciplinary failure               int64
# Education                          int64
# Son                                int64
# Social drinker                     int64
# Social smoker                      int64
# Pet                                int64
# Weight                             int64
# Height                             int64
# Body mass index                    int64
# Absenteeism time in hours          int64
# dtype: object

# %%
Absenteesim_Data.nunique()
# Out:
# ID                                 36
# Reason for absence                 28
# Month of absence                   13
# Day of the week                     5
# Seasons                             4
# Transportation expense             24
# Distance from Residence to Work    25
# Service time                       18
# Age                                22
# Work load Average/day              38
# Hit target                         13
# Disciplinary failure                2
# Education                           4
# Son                                 5
# Social drinker                      2
# Social smoker                       2
# Pet                                 6
# Weight                             26
# Height                             14
# Body mass index                    17
# Absenteeism time in hours          19
# dtype: int64

# %%
Absenteesim_Data.isnull().sum() #There is no null values present in the dataset
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
#for Identifying the categorical and Continuos variables in the dataset
for i in Absenteesim_Data.columns:
    print(i,"--", len(Absenteesim_Data[i].value_counts()))
    
#From the below output of the data
# Out:
# ID -- 36
# Reason for absence -- 28
# Month of absence -- 13
# Day of the week -- 5
# Seasons -- 4
# Transportation expense -- 24
# Distance from Residence to Work -- 25
# Service time -- 18
# Age -- 22
# Work load Average/day  -- 38
# Hit target -- 13
# Disciplinary failure -- 2
# Education -- 4
# Son -- 5
# Social drinker -- 2
# Social smoker -- 2
# Pet -- 6
# Weight -- 26
# Height -- 14
# Body mass index -- 17
# Absenteeism time in hours -- 19

# %%
Absenteesim_Data.isnull().sum()
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
Absenteesim_Data.columns
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
#Converting colmnns into categorical factors as they contain unqiue values
categorical_Data = ["Reason for absence","Month of absence","Day of the week","Seasons","Disciplinary failure","Education","Social drinker","Social smoker"]

# %%
numerical_Data = ["ID","Transportation expense","Distance from Residence to Work","Service time","Age",\
                 "Work load Average/day ","Hit target","Son","Pet","Weight","Height","Body mass index",\
                 "Absenteeism time in hours"]

# %%
Absenteesim_Data.dtypes
# Out:
# ID                                 int64
# Reason for absence                 int64
# Month of absence                   int64
# Day of the week                    int64
# Seasons                            int64
# Transportation expense             int64
# Distance from Residence to Work    int64
# Service time                       int64
# Age                                int64
# Work load Average/day              int64
# Hit target                         int64
# Disciplinary failure               int64
# Education                          int64
# Son                                int64
# Social drinker                     int64
# Social smoker                      int64
# Pet                                int64
# Weight                             int64
# Height                             int64
# Body mass index                    int64
# Absenteeism time in hours          int64
# dtype: object

# %%
Absenteesim_Data.isnull().sum()
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
#Visualisation part
Absenteesim_Data.hist(figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A10F33E7F0>,
# ...
#       dtype=object)

# %%
Absenteesim_Data.plot(kind='density', subplots=True, layout=(8,3), sharex=False)
plt.subplots_adjust(left=0, bottom=1, right=2, top= 5,wspace=0.2, hspace=0.2)

# %%
Absenteesim_Data.plot(kind='box', subplots=True, layout=(8,3), sharex=False, sharey=False, fontsize=8)
plt.subplots_adjust(left=0, bottom=1, right=2, top= 5,wspace=0.2, hspace=0.2)

# %%
#As per the box plot below are the variable having the outlier
#'Transportation expense','Service time','Age','Work load Average/day ','Hit target','Height','Absenteeism time in hours'
#Capping the outlier
for i in ['Transportation expense','Service time','Age','Work load Average/day ','Hit target','Height','Absenteeism time in hours']:
    q75,q25 = np.percentile(Absenteesim_Data.loc[:,i],[75,25])
    iqr = q75-q25
    min = q25-1.5*iqr
    max = q75+1.5*iqr
    Absenteesim_Data.loc[Absenteesim_Data[i] < min,i] = min
    Absenteesim_Data.loc[Absenteesim_Data[i] > max,i] = max

# %%
#Checking the outlier after capping
Absenteesim_Data.boxplot(column = ['Transportation expense','Service time','Age'])

# %%
Absenteesim_Data.boxplot(column = ['Work load Average/day ','Hit target'])

# %%
Absenteesim_Data.boxplot(column = ['Height','Absenteeism time in hours'])

# %%
#Correlation 
f = plt.figure(figsize=(30, 30))
plt.matshow(Absenteesim_Data.corr(), fignum=f.number)
plt.xticks(range(Absenteesim_Data.shape[1]), Absenteesim_Data.columns, fontsize=14, rotation=45)
plt.yticks(range(Absenteesim_Data.shape[1]), Absenteesim_Data.columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);

# %%
sns.countplot(x="Education", data= Absenteesim_Data)

# %%
Absenteesim_Data.columns
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
sns.countplot(x='Month of absence', hue='Absenteeism time in hours', data=Absenteesim_Data)

# %%
def Relationship_two_Variable(a,b):
    Relation = Absenteesim_Data.groupby(a)[b].sum()
    Relation = Relation.reset_index()
    Relation[b] = (Relation[b]*100)/sum(Absenteesim_Data[b])
    Relation = Relation.sort_values(by=['Absenteeism time in hours'])
    print(Relationship_two_Variable)
    return Relation.plot.barh(x=a,y=b)

# %%
Relationship_two_Variable('Reason for absence','Absenteeism time in hours')
# Out:
# <function Relationship_two_Variable at 0x000001A1102A18C8>

# %% [markdown]
# Top 5 categories in order of Absenteeism time in hours are:
#     1. 13 - Diseases of the musculoskeletal system and connective tissue
#     2. 19 - Injury, poisoning and certain other consequences of external causes
#     3. 23 - Medical consultation
#     4. 28 - Dental consultation
#     5. 11 - Diseases of the digestive system

# %%
Relationship_two_Variable('Month of absence','Absenteeism time in hours')
# Out:
# <function Relationship_two_Variable at 0x000001A1102A18C8>

# %% [markdown]
# Top 3 months in order of absenteesim time in hours is:
#     1. Month 3: March
#     2. Month 7: July
#     3. Month 4: April

# %%
Relationship_two_Variable('Day of the week','Absenteeism time in hours')
# Out:
# <function Relationship_two_Variable at 0x000001A1102A18C8>

# %% [markdown]
# Top 3 days in order of absenteesim time in hours is:
#     1. Day 2: Monday
#     2. Day 3: Tuesday
#     3. Day 4: Wednesday

# %%
Relationship_two_Variable('Education','Absenteeism time in hours')
# Out:
# <function Relationship_two_Variable at 0x000001A1102A18C8>

# %% [markdown]
# Top Education in order of absenteesim time in hours is:
#     1. Education:1 - High School

# %%
Relationship_two_Variable('Son','Absenteeism time in hours')
# Out:
# <function Relationship_two_Variable at 0x000001A1102A18C8>

# %% [markdown]
# Top 3 values in order of Absenteeism time in hours are:
#     1. 2:Two children
#     2. 0:No child
#     3. 1:One child

# %%
Relationship_two_Variable('Social drinker','Absenteeism time in hours')
# Out:
# <function Relationship_two_Variable at 0x000001A1102A18C8>

# %% [markdown]
# People who are drinkers are taking most of Absenteeism time in hours. But as drinking is not allowed at workplace this feature cannot give any solid conclusion.

# %%
Relationship_two_Variable('Social smoker','Absenteeism time in hours')
# Out:
# <function Relationship_two_Variable at 0x000001A1102A18C8>

# %% [markdown]
# People who are not social smokers are taking most of Absenteeism time in hours.

# %%
Relationship_two_Variable('Age','Absenteeism time in hours')
# Out:
# <function Relationship_two_Variable at 0x000001A1102A18C8>

# %%
#Feature variable X
X = Absenteesim_Data.iloc[:,:-1]
#taking the response variable
y = Absenteesim_Data['Absenteeism time in hours']

# %%
#importing the sklearn libraries
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.7, test_size=0.3, random_state=100)

# %%
#Building the Linear model
import statsmodels.api as sm          # Importing statsmodels
X_train = sm.add_constant(X_train)    # Adding a constant column to our dataframe
# create a first fitted model
lm_1 = sm.OLS(y_train,X_train).fit()
# Out:
# C:\Users\n.sharnappa.madem\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
print(lm_1.summary())
# Out:
#                                 OLS Regression Results
# ...
# Dep. Variable:     Absenteeism time in hours   R-squared:                       0.373
# Model:                                   OLS   Adj. R-squared:                  0.347
# Method:                        Least Squares   F-statistic:                     14.76
# Date:                       Sun, 26 Jan 2020   Prob (F-statistic):           8.44e-39
# Time:                               18:48:47   Log-Likelihood:                -1367.2
# No. Observations:                        518   AIC:                             2776.
# Df Residuals:                            497   BIC:                             2866.
# Df Model:                                 20
# Covariance Type:                   nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %%
# VIF for calculating vif value
def vif_cal(input_data, dependent_col):
    vif_df = pd.DataFrame( columns = ['Var', 'Vif'])
    x_vars=input_data.drop([dependent_col], axis=1)
    xvar_names=x_vars.columns
    for i in range(0,xvar_names.shape[0]):
        y=x_vars[xvar_names[i]] 
        x=x_vars[xvar_names.drop(xvar_names[i])]
        rsq=sm.OLS(y,x).fit().rsquared  
        vif=round(1/(1-rsq),2)
        vif_df.loc[i] = [xvar_names[i], vif]
    return vif_df.sort_values(by = 'Vif', axis=0, ascending=False, inplace=False)

# %%
vif_cal(input_data=Absenteesim_Data, dependent_col="Absenteeism time in hours")
# Out:
#                                 Var      Vif
# 18                           Height  1658.14
# 10                       Hit target  1125.42
# 17                           Weight   432.44
# 19                  Body mass index   429.02
# 8                               Age   106.00
# 9            Work load Average/day     61.98
# 7                      Service time    35.91
# 5            Transportation expense    22.88
# 6   Distance from Residence to Work    12.99
# 1                Reason for absence     9.65
# 3                   Day of the week     9.38
# 0                                ID     9.16
# 12                        Education     8.98
# 4                           Seasons     8.63
# 2                  Month of absence     7.80
# 14                   Social drinker     6.61
# 13                              Son     2.66
# 16                              Pet     2.31
# 11             Disciplinary failure     1.61
# 15                    Social smoker     1.39

# %%
# Let's see the correlation matrix 
plt.figure(figsize = (16,10))     # Size of the figure
sns.heatmap(Absenteesim_Data.corr(),annot = True)

# %%
#Dropping the variable and updating the model
X_train = X_train.drop('Seasons', 1)

# %%
#Creating the fitted model
lm_2 = sm.OLS(y_train, X_train).fit()
print(lm_2.summary())
# Out:
#                                 OLS Regression Results
# ...
# Dep. Variable:     Absenteeism time in hours   R-squared:                       0.373
# Model:                                   OLS   Adj. R-squared:                  0.349
# Method:                        Least Squares   F-statistic:                     15.57
# Date:                       Sun, 26 Jan 2020   Prob (F-statistic):           2.10e-39
# Time:                               18:48:58   Log-Likelihood:                -1367.2
# No. Observations:                        518   AIC:                             2774.
# Df Residuals:                            498   BIC:                             2859.
# Df Model:                                 19
# Covariance Type:                   nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %%
X_train = X_train.drop('Month of absence',1)

# %%
lm_3 = sm.OLS(y_train,X_train).fit()
print(lm_3.summary())
# Out:
#                                 OLS Regression Results
# ...
# Dep. Variable:     Absenteeism time in hours   R-squared:                       0.373
# Model:                                   OLS   Adj. R-squared:                  0.350
# Method:                        Least Squares   F-statistic:                     16.47
# Date:                       Sun, 26 Jan 2020   Prob (F-statistic):           5.09e-40
# Time:                               18:48:58   Log-Likelihood:                -1367.2
# No. Observations:                        518   AIC:                             2772.
# Df Residuals:                            499   BIC:                             2853.
# Df Model:                                 18
# Covariance Type:                   nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %%
X_train = X_train.drop('Age',1)

# %%
lm_4 = sm.OLS(y_train,X_train).fit()
print(lm_4.summary())
# Out:
#                                 OLS Regression Results
# ...
# Dep. Variable:     Absenteeism time in hours   R-squared:                       0.373
# Model:                                   OLS   Adj. R-squared:                  0.351
# Method:                        Least Squares   F-statistic:                     17.46
# Date:                       Sun, 26 Jan 2020   Prob (F-statistic):           1.25e-40
# Time:                               18:48:58   Log-Likelihood:                -1367.2
# No. Observations:                        518   AIC:                             2770.
# Df Residuals:                            500   BIC:                             2847.
# Df Model:                                 17
# Covariance Type:                   nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %%
X_train = X_train.drop('Hit target',1)

# %%
lm_5 = sm.OLS(y_train,X_train).fit()
print(lm_5.summary())
# Out:
#                                 OLS Regression Results
# ...
# Dep. Variable:     Absenteeism time in hours   R-squared:                       0.372
# Model:                                   OLS   Adj. R-squared:                  0.352
# Method:                        Least Squares   F-statistic:                     18.54
# Date:                       Sun, 26 Jan 2020   Prob (F-statistic):           3.55e-41
# Time:                               18:48:58   Log-Likelihood:                -1367.5
# No. Observations:                        518   AIC:                             2769.
# Df Residuals:                            501   BIC:                             2841.
# Df Model:                                 16
# Covariance Type:                   nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %%
#dropping the Height variable
X_train = X_train.drop('Height',1)

# %%
lm_6 = sm.OLS(y_train,X_train).fit()
print(lm_6.summary())
# Out:
#                                 OLS Regression Results
# ...
# Dep. Variable:     Absenteeism time in hours   R-squared:                       0.372
# Model:                                   OLS   Adj. R-squared:                  0.353
# Method:                        Least Squares   F-statistic:                     19.80
# Date:                       Sun, 26 Jan 2020   Prob (F-statistic):           8.39e-42
# Time:                               18:48:59   Log-Likelihood:                -1367.6
# No. Observations:                        518   AIC:                             2767.
# Df Residuals:                            502   BIC:                             2835.
# Df Model:                                 15
# Covariance Type:                   nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %%
X_train = X_train.drop('Social smoker',1)

# %%
lm_7 = sm.OLS(y_train,X_train).fit()
print(lm_7.summary())
# Out:
#                                 OLS Regression Results
# ...
# Dep. Variable:     Absenteeism time in hours   R-squared:                       0.371
# Model:                                   OLS   Adj. R-squared:                  0.353
# Method:                        Least Squares   F-statistic:                     21.17
# Date:                       Sun, 26 Jan 2020   Prob (F-statistic):           2.65e-42
# Time:                               18:48:59   Log-Likelihood:                -1368.0
# No. Observations:                        518   AIC:                             2766.
# Df Residuals:                            503   BIC:                             2830.
# Df Model:                                 14
# Covariance Type:                   nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %%
X_train = X_train.drop('Education',1)

# %%
lm_8 = sm.OLS(y_train,X_train).fit()
print(lm_8.summary())
# Out:
#                                 OLS Regression Results
# ...
# Dep. Variable:     Absenteeism time in hours   R-squared:                       0.369
# Model:                                   OLS   Adj. R-squared:                  0.353
# Method:                        Least Squares   F-statistic:                     22.66
# Date:                       Sun, 26 Jan 2020   Prob (F-statistic):           1.12e-42
# Time:                               18:49:00   Log-Likelihood:                -1368.8
# No. Observations:                        518   AIC:                             2766.
# Df Residuals:                            504   BIC:                             2825.
# Df Model:                                 13
# Covariance Type:                   nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %%
X_train = X_train.drop('Pet',1)

# %%
lm_9 = sm.OLS(y_train,X_train).fit()
print(lm_9.summary())
# Out:
#                                 OLS Regression Results
# ...
# Dep. Variable:     Absenteeism time in hours   R-squared:                       0.367
# Model:                                   OLS   Adj. R-squared:                  0.352
# Method:                        Least Squares   F-statistic:                     24.37
# Date:                       Sun, 26 Jan 2020   Prob (F-statistic):           4.95e-43
# Time:                               18:49:01   Log-Likelihood:                -1369.6
# No. Observations:                        518   AIC:                             2765.
# Df Residuals:                            505   BIC:                             2820.
# Df Model:                                 12
# Covariance Type:                   nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %%
X_train = X_train.drop('Service time',1)

# %%
lm_10 =sm.OLS(y_train,X_train).fit()
print(lm_10.summary())
# Out:
#                                 OLS Regression Results
# ...
# Dep. Variable:     Absenteeism time in hours   R-squared:                       0.366
# Model:                                   OLS   Adj. R-squared:                  0.352
# Method:                        Least Squares   F-statistic:                     26.57
# Date:                       Sun, 26 Jan 2020   Prob (F-statistic):           1.16e-43
# Time:                               18:49:05   Log-Likelihood:                -1369.9
# No. Observations:                        518   AIC:                             2764.
# Df Residuals:                            506   BIC:                             2815.
# Df Model:                                 11
# Covariance Type:                   nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %%
X_train = X_train.drop('Work load Average/day ',1)

# %%
lm_11 = sm.OLS(y_train,X_train).fit()
print(lm_11.summary())
# Out:
#                                 OLS Regression Results
# ...
# Dep. Variable:     Absenteeism time in hours   R-squared:                       0.364
# Model:                                   OLS   Adj. R-squared:                  0.351
# Method:                        Least Squares   F-statistic:                     28.98
# Date:                       Sun, 26 Jan 2020   Prob (F-statistic):           5.47e-44
# Time:                               18:49:07   Log-Likelihood:                -1370.9
# No. Observations:                        518   AIC:                             2764.
# Df Residuals:                            507   BIC:                             2810.
# Df Model:                                 10
# Covariance Type:                   nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %%
X_train = X_train.drop('Weight',1)

# %%
lm_12 = sm.OLS(y_train,X_train).fit()
print(lm_12.summary())
# Out:
#                                 OLS Regression Results
# ...
# Dep. Variable:     Absenteeism time in hours   R-squared:                       0.360
# Model:                                   OLS   Adj. R-squared:                  0.349
# Method:                        Least Squares   F-statistic:                     31.80
# Date:                       Sun, 26 Jan 2020   Prob (F-statistic):           3.39e-44
# Time:                               18:49:08   Log-Likelihood:                -1372.2
# No. Observations:                        518   AIC:                             2764.
# Df Residuals:                            508   BIC:                             2807.
# Df Model:                                  9
# Covariance Type:                   nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %%
# Adding  constant variable to test dataframe
X_test_m6 = sm.add_constant(X_test)
# Out:
# C:\Users\n.sharnappa.madem\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
X_test_m6 = X_test_m6.drop(['Seasons','Month of absence','Age','Hit target','Height','Social smoker','Education','Pet','Service time','Work load Average/day ','Weight'], axis=1)

# %%
X_test_m6.shape
# Out:
# (222, 10)

# %%
X_train.shape
# Out:
# (518, 10)

# %%
# Making predictions
y_pred_m6 = lm_12.predict(X_test_m6)

# %%
y_pred_m6
# Out:
# 569     7.907342
# 327     5.317448
# 277    -0.414538
# 19      3.314016
# 423     3.088964
# 519     7.852857
# 48      5.600791
# 395     6.419662
# 235     2.059295
# 598     2.599599
# 334     8.934296
# 513     0.936080
# 447     8.760347
# 605     2.841859
# 720     2.478152
# 418     2.604444
# 161     5.529033
# 493     4.472336
# 248     2.837015
# 461     2.771541
# 482     4.080183
# 635     6.172690
# 41      2.952982
# 73      3.488631
# 109     5.652133
# 590     2.599599
# 467     1.523645
# 637     7.771798
# 203    -0.092588
# 691     5.827215
#          ...
# 254     6.451343
# 201     8.098718
# 193     5.417154
# 320     4.176299
# 737    11.301606
# 522     5.901673
# 487     3.801210
# 174     3.488631
# 510     3.315079
# 353     8.076725
# 622     8.804530
# 527     5.278160
# 425     8.651314
# 155     3.324453
# 150     2.771541
# 78      4.930198
# 9       6.419662
# 142     4.176299
# 518     3.730891
# 75      8.280672
# 29      3.307001
# ...

# %%
# Plotting y_test and y_pred to understand the spread.
fig = plt.figure()
plt.scatter(y_test,y_pred_m6)
fig.suptitle('y_test vs y_pred', fontsize=20)              # Plot heading 
plt.xlabel('y_test', fontsize=18)                          # X-label
plt.ylabel('y_pred', fontsize=16)
# Out:
# Text(0, 0.5, 'y_pred')

# %%
#Feature variable X
X = Absenteesim_Data.iloc[:,:-1]
#taking the response variable
y = Absenteesim_Data['Absenteeism time in hours']

# %%
X.shape
# Out:
# (740, 20)

# %%
X_test.shape
# Out:
# (222, 20)

# %%
y_train.shape
# Out:
# (518,)

# %%
y_test.shape
# Out:
# (222,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
regressor=RandomForestRegressor()
regressor.fit(X_train,y_train)
# Out:
# C:\Users\n.sharnappa.madem\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(regressor.score(X_train, y_train)))
# Out:
# Coefficient of determination R^2 <-- on train set: 0.8742816488614579

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(regressor.score(X_test, y_test)))
# Out:
# Coefficient of determination R^2 <-- on train set: 0.4015724498893609

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(regressor,X,y,cv=5)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor=RandomForestRegressor()
regressor.fit(X_train,y_train)
# Out:
# C:\Users\n.sharnappa.madem\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(regressor.score(X_train, y_train)))
# Out:
# Coefficient of determination R^2 <-- on train set: 0.8238138929178973

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(regressor.score(X_test, y_test)))
# Out:
# Coefficient of determination R^2 <-- on train set: 0.4015724498893609

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(regressor,X,y,cv=5)

# %%
score.mean()
# Out:
# 0.30012482304706467

# %%
#model Evaluation
prediction=regressor.predict(X_test)

# %%
sns.distplot(y_test-prediction)

# %%
RandomForestRegressor()
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators='warn',
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
print(n_estimators)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
#Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]
# Method of selecting samples for training each tree
# bootstrap = [True, False]

# %%
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
# Use the random grid to search for best hyperparameters
# First create the base model to tune
rf = RandomForestRegressor()

# %%
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 100, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   0.6s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   0.7s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   0.5s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# ...

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 300,
#  'min_samples_split': 10,
#  'min_samples_leaf': 5,
#  'max_features': 'auto',
#  'max_depth': 20}

# %%
rf_random.best_score_
# Out:
# -11.851852548239616

# %%
predictions=rf_random.predict(X_test)

# %%
sns.distplot(y_test-predictions)

# %%
plt.scatter(y_test,prediction)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 2.334153898977115
# MSE: 11.448578216373974
# RMSE: 3.3835747688464006

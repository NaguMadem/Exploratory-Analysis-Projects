# %%
#Importing the necessart libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib.inline
import warnings
warnigs.filterwarnigs('ignore')
# Out:
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
#setting the current path 
os.chdir("C:\\Data Science\\Mindtree assignment\\")
data = pd.read_excel("Absenteeism_at_work.xls")
data.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#    Work load Average/day   ...  Disciplinary failure  Education  Son  \
# 0                  239554  ...                     0          1    2
# 1                  239554  ...                     1          1    1
# 2                  239554  ...                     0          1    0
# 3                  239554  ...                     0          1    2
# 4                  239554  ...                     0          1    2
#
#    Social drinker  Social smoker  Pet  Weight  Height  Body mass index  \
# 0               1              0    1      90     172               30
# 1               1              0    0      98     178               31
# 2               1              0    0      89     170               31
# 3               1              1    0      68     168               24
# 4               1              0    1      90     172               30
#
#    Absenteeism time in hours
# 0                          4
# 1                          0
# 2                          2
# 3                          4
# 4                          2
#
# [5 rows x 21 columns]

# %%
data.tail()
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 735                     289                               36            13
# 736                     235                               11            14
# 737                     118                               14            13
# 738                     231                               35            14
# 739                     179                               45            14
#
#      Age  Work load Average/day   ...  Disciplinary failure  Education  Son  \
# 735   33                  264604  ...                     0          1    2
# 736   37                  264604  ...                     0          3    1
# 737   40                  271219  ...                     0          1    1
# 738   39                  271219  ...                     0          1    2
# 739   53                  271219  ...                     0          1    1
#
#      Social drinker  Social smoker  Pet  Weight  Height  Body mass index  \
# 735               1              0    1      90     172               30
# 736               0              0    1      88     172               29
# 737               1              0    8      98     170               34
# 738               1              0    2     100     170               35
# 739               0              0    1      77     175               25
#
#      Absenteeism time in hours
# 735                          8
# 736                          4
# 737                          0
# 738                          0
# 739                          0
#
# [5 rows x 21 columns]

# %%
data.shape
# Out:
# (740, 21)

# %%
data.describe()
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  740.000000          740.000000        740.000000       740.000000
# mean    18.017568           19.216216          6.324324         3.914865
# std     11.021247            8.433406          3.436287         1.421675
# min      1.000000            0.000000          0.000000         2.000000
# 25%      9.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          6.000000         4.000000
# 75%     28.000000           26.000000          9.000000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  740.000000              740.000000                       740.000000
# mean     2.544595              221.329730                        29.631081
# std      1.111831               66.952223                        14.836788
# min      1.000000              118.000000                         5.000000
# 25%      2.000000              179.000000                        16.000000
# 50%      3.000000              225.000000                        26.000000
# 75%      4.000000              260.000000                        50.000000
# max      4.000000              388.000000                        52.000000
#
#        Service time         Age  Work load Average/day   ...  \
# count    740.000000  740.000000              740.000000  ...
# mean      12.554054   36.450000           271490.235135  ...
# std        4.384873    6.478772            39058.116188  ...
# min        1.000000   27.000000           205917.000000  ...
# 25%        9.000000   31.000000           244387.000000  ...
# 50%       13.000000   37.000000           264249.000000  ...
# 75%       16.000000   40.000000           294217.000000  ...
# max       29.000000   58.000000           378884.000000  ...
#
#        Disciplinary failure   Education         Son  Social drinker  \
# count            740.000000  740.000000  740.000000      740.000000
# mean               0.054054    1.291892    1.018919        0.567568
# std                0.226277    0.673238    1.098489        0.495749
# min                0.000000    1.000000    0.000000        0.000000
# 25%                0.000000    1.000000    0.000000        0.000000
# 50%                0.000000    1.000000    1.000000        1.000000
# 75%                0.000000    1.000000    2.000000        1.000000
# max                1.000000    4.000000    4.000000        1.000000
#
#        Social smoker         Pet      Weight      Height  Body mass index  \
# count     740.000000  740.000000  740.000000  740.000000       740.000000
# mean        0.072973    0.745946   79.035135  172.114865        26.677027
# std         0.260268    1.318258   12.883211    6.034995         4.285452
# min         0.000000    0.000000   56.000000  163.000000        19.000000
# 25%         0.000000    0.000000   69.000000  169.000000        24.000000
# 50%         0.000000    0.000000   83.000000  170.000000        25.000000
# 75%         0.000000    1.000000   89.000000  172.000000        31.000000
# max         1.000000    8.000000  108.000000  196.000000        38.000000
#
#        Absenteeism time in hours
# count                 740.000000
# mean                    6.924324
# std                    13.330998
# min                     0.000000
# 25%                     2.000000
# 50%                     3.000000
# 75%                     8.000000
# max                   120.000000
#
# [8 rows x 21 columns]

# %%
data.dtypes
# Out:
# ID                                 int64
# Reason for absence                 int64
# Month of absence                   int64
# Day of the week                    int64
# Seasons                            int64
# Transportation expense             int64
# Distance from Residence to Work    int64
# Service time                       int64
# Age                                int64
# Work load Average/day              int64
# Hit target                         int64
# Disciplinary failure               int64
# Education                          int64
# Son                                int64
# Social drinker                     int64
# Social smoker                      int64
# Pet                                int64
# Weight                             int64
# Height                             int64
# Body mass index                    int64
# Absenteeism time in hours          int64
# dtype: object

# %%
data.columns
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
data.nunique()
# Out:
# ID                                 36
# Reason for absence                 27
# Month of absence                   12
# Day of the week                     5
# Seasons                             4
# Transportation expense             23
# Distance from Residence to Work    25
# Service time                       17
# Age                                21
# Work load Average/day              36
# Hit target                         12
# Disciplinary failure                2
# Education                           4
# Son                                 5
# Social drinker                      2
# Social smoker                       2
# Pet                                 3
# Height                              9
# Body mass index                    17
# Absenteeism time in hours           9
# dtype: int64

# %%
#Divinding the data set into Categiorical and Numerical data set
categorical_set = ["Reason for absence","Month of absence","Day of the week","Seasons","Disciplinary failure","Education","Social drinker","Social smoker"]

# %%
numerical_set = ["ID","Transportation expense","Distance from Residence to Work","Service time","Age",\
                 "Work load Average/day ","Hit target","Son","Pet","Weight","Height","Body mass index",\
                 "Absenteeism time in hours"]

# %%
# Converting categorical_set data into category types from int/float
for i in categorical_set :
    data[i] = data[i].astype("category")

# %%
data.dtypes # Updated Data Types
# Out:
# ID                                    int64
# Reason for absence                 category
# Month of absence                   category
# Day of the week                    category
# Seasons                            category
# Transportation expense                int64
# Distance from Residence to Work       int64
# Service time                          int64
# Age                                   int64
# Work load Average/day                 int64
# Hit target                            int64
# Disciplinary failure               category
# Education                          category
# Son                                   int64
# Social drinker                     category
# Social smoker                      category
# Pet                                   int64
# Weight                                int64
# Height                                int64
# Body mass index                       int64
# Absenteeism time in hours             int64
# dtype: object

# %%
for i in ["Reason for absence","Month of absence","Day of the week","Seasons","Education","ID","Age","Weight","Height","Body mass index"]:
        data[i] = data[i].replace(0,np.nan)

# %%
NA_data = pd.DataFrame(data.isnull().sum())
NA_data = NA_data.rename(columns={0:"NA_sum"})
NA_data["NA_percent"] = (NA_data["NA_sum"]/len(data))*100
NA_data
# Out:
#                                  NA_sum  NA_percent
# ID                                    0    0.000000
# Reason for absence                   43    5.810811
# Month of absence                      3    0.405405
# Day of the week                       0    0.000000
# Seasons                               0    0.000000
# Transportation expense                0    0.000000
# Distance from Residence to Work       0    0.000000
# Service time                          0    0.000000
# Age                                   0    0.000000
# Work load Average/day                 0    0.000000
# Hit target                            0    0.000000
# Disciplinary failure                  0    0.000000
# Education                             0    0.000000
# Son                                   0    0.000000
# Social drinker                        0    0.000000
# Social smoker                         0    0.000000
# Pet                                   0    0.000000
# Weight                                0    0.000000
# Height                                0    0.000000
# Body mass index                       0    0.000000
# Absenteeism time in hours             0    0.000000

# %%
for i in range(0,len(NA_data)):
    if(NA_data["NA_percent"][i]>=30):
        data.drop([i],axis = 1)
        # update numerical and categorical set as well
        if(i in numerical_set):
            numerical_set.remove(i)
        else :
            categorical_set.remove(i)

# %%
# Median method for numerical features
# Mode for categorical features
import statistics
def impute_median_mode(data_set):
    for i in data_set.columns.values:
        if data_set.loc[:,i].dtypes.name == 'int64'or data_set.loc[:,i].dtypes.name == 'float64':
            data_set[i] = data_set[i].fillna(data_set[i].median())
            
        elif data_set.loc[:,i].dtypes.name == 'category':
            data_set[i] = data_set[i].fillna(statistics.mode(data_set[i]))
            
            
    return data_set

# %%
data.isnull().sum().sum() # total number of NAN values in the dataset
# Out:
# 46

# %%
if(data.isnull().sum().sum()!=0):
    data = impute_median_mode(data)

# %%
data.isnull().sum() # check for missing values
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
def relationship(a,b):
    df = data.groupby(a)[b].sum()
    df = df.reset_index()
    df[b] = (df[b]*100)/sum(data[b])
    df = df.sort_values(by=['Absenteeism time in hours'])
    print(df)
    return df.plot.barh(x=a,y=b, figsize = (12,10))

# %%
relationship('Reason for absence','Absenteeism time in hours')
# Out:
#    Reason for absence  Absenteeism time in hours
# 0                   0                   0.000000
# 16                 16                   0.117096
# 17                 17                   0.156128
# 3                   3                   0.156128
# 4                   4                   0.175644
# 15                 15                   0.312256
# 5                   5                   0.370804
# 23                 24                   0.468384
# 2                   2                   0.468384
# 8                   8                   0.624512
# 20                 21                   0.683060
# 24                 25                   2.107728
# 7                   7                   2.927400
# 26                 27                   3.064012
# 14                 14                   3.259173
# 9                   9                   3.278689
# 6                   6                   3.337237
# 1                   1                   3.551913
# 12                 12                   3.649493
# 18                 18                   4.234973
# 25                 26                   4.683841
# 10                 10                   5.386417
# 21                 22                   5.718189
# 11                 11                   5.796253
# 27                 28                   6.537861
# 22                 23                   8.274785
# 19                 19                  14.227166
# 13                 13                  16.432475

# %%
relationship('Month of absence','Absenteeism time in hours')
# Out:
#    Month of absence  Absenteeism time in hours
# 0                 0                   0.000000
# 1                 1                   4.332553
# 8                 8                   5.620609
# 9                 9                   5.698673
# 2                 2                   5.737705
# 10               10                   6.811085
# 5                 5                   7.806401
# 6                 6                   8.021077
# 12               12                   8.079625
# 11               11                   9.231069
# 4                 4                   9.406714
# 7                 7                  14.324746
# 3                 3                  14.929742

# %%
relationship('Day of the week','Absenteeism time in hours')
# Out:
#   Day of the week  Absenteeism time in hours
# 3               5                  10.792350
# 4               6                  14.402810
# 2               4                  21.760343
# 1               3                  23.985168
# 0               2                  29.059329

# %%
relationship('Education','Absenteeism time in hours')
# Out:
#   Education  Absenteeism time in hours
# 3         4                   0.409836
# 1         2                   5.737705
# 2         3                   8.118657
# 0         1                  85.733802

# %%
relationship('Son','Absenteeism time in hours')
# Out:
#    Son  Absenteeism time in hours
# 3    3                   3.571429
# 4    4                   5.971897
# 1    1                  26.951600
# 0    0                  31.323185
# 2    2                  32.181889

# %%
relationship('Social drinker','Absenteeism time in hours')
# Out:
#   Social drinker  Absenteeism time in hours
# 0              0                  37.041374
# 1              1                  62.958626

# %%
relationship('Social smoker','Absenteeism time in hours')
# Out:
#   Social smoker  Absenteeism time in hours
# 1             1                   6.850117
# 0             0                  93.149883

# %%
relationship('Age','Absenteeism time in hours')
# Out:
#     Age  Absenteeism time in hours
# 20   53                   0.000000
# 18   49                   0.312256
# 15   46                   0.312256
# 17   48                   0.487900
# 0    27                   0.526932
# 11   39                   0.585480
# 2    29                   0.604996
# 5    32                   0.936768
# 16   47                   1.424668
# 14   43                   3.649493
# 4    31                   4.234973
# 3    30                   4.937549
# 21   58                   5.113193
# 13   41                   5.366901
# 19   50                   6.381733
# 8    36                   6.752537
# 12   40                   7.396565
# 9    37                   9.074941
# 7    34                   9.289617
# 10   38                   9.406714
# 6    33                  10.499610
# 1    28                  12.704918

# %%
for i in numerical_set:
    print(i)
    q75,q25 = np.percentile(data[i],[75,25])
    iqr = q75-q25
    min_bar = (q25-(1.5*iqr))
    max_bar = (q75+(1.5*iqr))
    print(min_bar,max_bar)
    data.loc[data[i]<min_bar,i] = np.nan
    data.loc[data[i]>max_bar,i] = np.nan
# Out:
# ID
# -19.5 56.5
# Transportation expense
# 57.5 381.5
# Distance from Residence to Work
# -35.0 101.0
# Service time
# -1.5 26.5
# Age
# 17.5 53.5
# Work load Average/day
# 169642.0 368962.0
# Hit target
# 87.0 103.0
# Son
# -3.0 5.0
# Pet
# -1.5 2.5
# Weight
# 39.0 119.0
# Height
# 164.5 176.5
# Body mass index
# 13.5 41.5
# Absenteeism time in hours
# -7.0 17.0

# %%
data = impute_median_mode(data) # function call

# %%
sns.pairplot(data[numerical_set[0:13]])

# %%
sns.heatmap(data[numerical_set].corr()) # Heat Map of the correlation between the features

# %%
data[numerical_set].corr() # Correlation between features
# Out:
#                                        ID  Transportation expense  \
# ID                               1.000000               -0.238838
# Transportation expense          -0.238838                1.000000
# Distance from Residence to Work -0.486160                0.275428
# Service time                    -0.319710               -0.390977
# Age                              0.074242               -0.272291
# Work load Average/day            0.109667               -0.029304
# Hit target                      -0.038674               -0.083278
# Son                              0.002767                0.397214
# Pet                              0.188808                0.220012
# Weight                          -0.254222               -0.207745
# Height                          -0.082727               -0.005938
# Body mass index                 -0.306924               -0.132020
# Absenteeism time in hours       -0.135230                0.192522
#
#                                  Distance from Residence to Work  \
# ID                                                     -0.486160
# Transportation expense                                  0.275428
# Distance from Residence to Work                         1.000000
# Service time                                            0.106384
# Age                                                    -0.116169
# Work load Average/day                                  -0.084675
# Hit target                                              0.028707
# Son                                                     0.054230
# Pet                                                    -0.107988
# Weight                                                 -0.047859
# Height                                                 -0.068603
# Body mass index                                         0.113772
# Absenteeism time in hours                               0.015408
#
#                                  Service time       Age  \
# ID                                  -0.319710  0.074242
# Transportation expense              -0.390977 -0.272291
# Distance from Residence to Work      0.106384 -0.116169
# Service time                         1.000000  0.667026
# Age                                  0.667026  1.000000
# Work load Average/day               -0.064813 -0.065524
# Hit target                           0.066686 -0.003435
# Son                                 -0.025479  0.027352
# Pet                                 -0.172316 -0.249161
# Weight                               0.421130  0.487374
# Height                              -0.069120 -0.114714
# Body mass index                      0.469020  0.542863
# Absenteeism time in hours           -0.087922 -0.103250
#
#                                  Work load Average/day   Hit target       Son  \
# ID                                             0.109667   -0.038674  0.002767
# Transportation expense                        -0.029304   -0.083278  0.397214
# Distance from Residence to Work               -0.084675    0.028707  0.054230
# Service time                                  -0.064813    0.066686 -0.025479
# Age                                           -0.065524   -0.003435  0.027352
# Work load Average/day                          1.000000    0.047340  0.054374
# Hit target                                     0.047340    1.000000 -0.036244
# Son                                            0.054374   -0.036244  1.000000
# Pet                                            0.115771   -0.031963  0.153519
# Weight                                        -0.092135   -0.004883 -0.139552
# Height                                        -0.058425    0.009858 -0.297051
# Body mass index                               -0.117449   -0.037321 -0.144150
# Absenteeism time in hours                      0.038718    0.030020  0.135417
#
#                                       Pet    Weight    Height  \
# ID                               0.188808 -0.254222 -0.082727
# Transportation expense           0.220012 -0.207745 -0.005938
# Distance from Residence to Work -0.107988 -0.047859 -0.068603
# Service time                    -0.172316  0.421130 -0.069120
# Age                             -0.249161  0.487374 -0.114714
# Work load Average/day            0.115771 -0.092135 -0.058425
# Hit target                      -0.031963 -0.004883  0.009858
# Son                              0.153519 -0.139552 -0.297051
# Pet                              1.000000 -0.110402 -0.127360
# Weight                          -0.110402  1.000000  0.034853
# Height                          -0.127360  0.034853  1.000000
# Body mass index                 -0.043192  0.904117 -0.118993
# Absenteeism time in hours       -0.042655 -0.024366  0.041809
#
#                                  Body mass index  Absenteeism time in hours
# ID                                     -0.306924                  -0.135230
# Transportation expense                 -0.132020                   0.192522
# Distance from Residence to Work         0.113772                   0.015408
# Service time                            0.469020                  -0.087922
# Age                                     0.542863                  -0.103250
# Work load Average/day                  -0.117449                   0.038718
# Hit target                             -0.037321                   0.030020
# Son                                    -0.144150                   0.135417
# Pet                                    -0.043192                  -0.042655
# Weight                                  0.904117                  -0.024366
# Height                                 -0.118993                   0.041809
# Body mass index                         1.000000                  -0.039542
# Absenteeism time in hours              -0.039542                   1.000000

# %%
data = data.drop(["Weight"],axis = 1)
data.head()
# Out:
#      ID Reason for absence Month of absence Day of the week Seasons  \
# 0  11.0                 26                7               3       1
# 1  36.0                 23                7               3       1
# 2   3.0                 23                7               4       1
# 3   7.0                  7                7               5       1
# 4  11.0                 23                7               5       1
#
#    Transportation expense  Distance from Residence to Work  Service time  \
# 0                   289.0                             36.0          13.0
# 1                   118.0                             13.0          18.0
# 2                   179.0                             51.0          18.0
# 3                   279.0                              5.0          14.0
# 4                   289.0                             36.0          13.0
#
#     Age  Work load Average/day   Hit target Disciplinary failure Education  \
# 0  33.0                239554.0        97.0                    0         1
# 1  50.0                239554.0        97.0                    1         1
# 2  38.0                239554.0        97.0                    0         1
# 3  39.0                239554.0        97.0                    0         1
# 4  33.0                239554.0        97.0                    0         1
#
#    Son Social drinker Social smoker  Pet  Height  Body mass index  \
# 0  2.0              1             0  1.0   172.0             30.0
# 1  1.0              1             0  0.0   170.0             31.0
# 2  0.0              1             0  0.0   170.0             31.0
# 3  2.0              1             1  0.0   168.0             24.0
# 4  2.0              1             0  1.0   172.0             30.0
#
#    Absenteeism time in hours
# 0                        4.0
# 1                        0.0
# 2                        2.0
# 3                        4.0
# 4                        2.0

# %%
from sklearn.model_selection import train_test_split

# %%
# covert all features to float
data.dtypes
for i in data.columns.values:
    data[i] = data[i].astype('float')
    
data.dtypes
# Out:
# ID                                 float64
# Reason for absence                 float64
# Month of absence                   float64
# Day of the week                    float64
# Seasons                            float64
# Transportation expense             float64
# Distance from Residence to Work    float64
# Service time                       float64
# Age                                float64
# Work load Average/day              float64
# Hit target                         float64
# Disciplinary failure               float64
# Education                          float64
# Son                                float64
# Social drinker                     float64
# Social smoker                      float64
# Pet                                float64
# Height                             float64
# Body mass index                    float64
# Absenteeism time in hours          float64
# dtype: object

# %%
df_test, df_train = train_test_split(data,test_size = 0.25)

# %%
# Linear Regression 
from sklearn.linear_model import LinearRegression
# Decision trees
from sklearn.tree import DecisionTreeRegressor
# Random forest
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import math

# %%
modelDT = DecisionTreeRegressor(max_depth=2).fit(df_train.iloc[:,0:14], df_train.iloc[:,14])

# %%
predictDT = modelDT.predict(df_test.iloc[:,0:14])

# %%
# RMSE
math.sqrt(mean_squared_error(df_test.iloc[:,14],predictDT))
# Out:
# 0.2929378744932077

# %%
modelRF = RandomForestRegressor(max_depth=2,n_estimators=10,random_state=0,max_features=10).fit(df_train.iloc[:,0:14],\
                                                                                                df_train.iloc[:,14])
predictRF = modelRF.predict(df_test.iloc[:,0:14])
# RMSE
math.sqrt(mean_squared_error(df_test.iloc[:,14],predictRF))
# Out:
# 0.25290282050717694

# %%
lr = LinearRegression()
modelLR = lr.fit(df_train.iloc[:,0:14],df_train.iloc[:,14])
predictLR = modelLR.predict(df_test.iloc[:,0:14])
# RMSE 
math.sqrt(mean_squared_error(df_test.iloc[:,14],predictLR))
# Out:
# 0.3817925062105746

# %%
loss_data = data[["Month of absence","Work load Average/day ","Service time","Absenteeism time in hours"]]

# %%
loss_data["Work Loss"]=(data["Work load Average/day "]/data["Service time"])*data["Absenteeism time in hours"]
loss_data.sample(10)
# Out:
# C:\Users\n.sharnappa.madem\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#      Month of absence  Work load Average/day   Service time  \
# 213               5.0                264249.0          14.0
# 297              10.0                265017.0          12.0
# 467               7.0                230290.0          10.0
# 180               3.0                343253.0          14.0
# 258               8.0                265615.0          11.0
# 466               7.0                230290.0          11.0
# 470               7.0                230290.0          16.0
# 668               4.0                246288.0           8.0
# 32                8.0                205917.0          14.0
# 713               6.0                275089.0           9.0
#
#      Absenteeism time in hours      Work Loss
# 213                        0.0       0.000000
# 297                        8.0  176678.000000
# 467                        8.0  184232.000000
# 180                       16.0  392289.142857
# 258                        4.0   96587.272727
# 466                        4.0   83741.818182
# 470                        2.0   28786.250000
# 668                        3.0   92358.000000
# 32                         4.0   58833.428571
# 713                        2.0   61130.888889

# %%
monthly_loss = loss_data[["Month of absence","Work Loss"]]

# %%
monthly_loss = monthly_loss.groupby("Month of absence").sum()
monthly_loss
# Out:
#                      Work Loss
# Month of absence
# 1.0               4.773726e+06
# 2.0               7.938029e+06
# 3.0               1.066147e+07
# 4.0               6.140413e+06
# 5.0               6.709800e+06
# 6.0               1.011576e+07
# 7.0               1.149265e+07
# 8.0               6.967308e+06
# 9.0               4.159159e+06
# 10.0              7.355807e+06
# 11.0              6.666481e+06
# 12.0              7.760620e+06

# %%
monthly_loss.plot(kind='bar')
